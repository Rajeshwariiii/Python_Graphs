# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajeshwariiii/Python_Graphs/blob/main/graphs2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ea9ca503-0911-4dd3-a9dd-4aa91e47407e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ea9ca503-0911-4dd3-a9dd-4aa91e47407e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
Data = pd.read_excel(io.BytesIO(uploaded['survey_data']))
df = pd.DataFrame(Data)

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt


# Remove the 'Total' row from both tables
df_table1 = df_table1[df_table1['Survey response'] != 'Total']
df_table2 = df_table2[df_table2['Survey response'] != 'Total']

# Convert 'Frequency' column to integers for plotting
df_table1['Frequency'] = df_table1['Frequency'].astype(int)
df_table2['Frequency'] = df_table2['Frequency'].astype(int)

# Custom color palette
colors1 = ['orange', 'lightgreen', 'red']  # Colors for first chart
colors2 = ['lightcoral', 'skyblue', 'yellowgreen']  # Colors for second chart

# Plot 1: Enhanced Pie chart for Responses from Non-Student Adults
plt.figure(figsize=(14, 7))

plt.subplot(1, 2, 1)  # Create subplot for first pie chart
plt.pie(df_table1['Frequency'], labels=df_table1['Survey response'], autopct='%1.1f%%',
        startangle=90, colors=colors1, explode=[0.05]*3, shadow=True)
plt.title('Enhanced Pie Chart: Responses from Non-Student Adults', fontsize=14)

# Plot 2: Enhanced Pie chart for Responses from College Students
plt.subplot(1, 2, 2)  # Create subplot for second pie chart
plt.pie(df_table2['Frequency'], labels=df_table2['Survey response'], autopct='%1.1f%%',
        startangle=90, colors=colors2, explode=[0.05]*3, shadow=True)
plt.title('Enhanced Pie Chart: Responses from College Students', fontsize=14)

# Adjust the layout to display side by side
plt.tight_layout()
plt.show()
